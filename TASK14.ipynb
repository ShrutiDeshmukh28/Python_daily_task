# %%
1.
square = lambda x : x*x
print(square(5))
# Out:
# 25

# %%
2.
cube = lambda x: x*x*x
print(cube(4))
# Out:
# 64

# %%
3.
Add = lambda a,b:a+b
print(Add(10,20))
# Out:
# 30

# %%
4.
maximum = lambda a,b: a if a>b else b
print(maximum(15,8))
# Out:
# 15

# %%
5.
num = 9
check = lambda x : "Even" if x%2 ==0 else "Odd"
print(check(num))
# Out:
# Odd

# %%
6.
num = [1,2,3,4]
result = list(map(lambda x: x * x, num))
print(result)
# Out:
# [1, 4, 9, 16]

# %%
7.
numbers = [1,2,3,4,5,6]
result = list(filter(lambda x: x%2 ==0,numbers))
print(result)
# Out:
# [2, 4, 6]

# %%
8.
numbers = [20,45,55,70]
result = list(filter(lambda x: x > 50,numbers))
print(result)
# Out:
# [55, 70]

# %%
9.
ascending = [9,5,1,8,2]
result = sorted(ascending, key=lambda x:x)
print(result)
# Out:
# [1, 2, 5, 8, 9]

# %%
10.
descending = [9,5,1,8,2]
result = sorted(descending,key=lambda x:-x)
print(result)
# Out:
# [9, 8, 5, 2, 1]

# %% [markdown]
# ### Medium Level

# %%
11.
from functools import reduce
number = [10,20.30,40]
result=reduce(lambda x,y:x+y,number)
print(result)
# Out:
# 70.3

# %%
12.
from functools import reduce
numbers = [2,3,4,5]
result=reduce(lambda x,y: x * y,numbers)
print(result)
# Out:
# 120

# %%
13.
student = [
("Ram",22),
("Amit",19),
("Neha",25),
("Raj",20),
]
result= sorted(student,key = lambda x:x[1])
print(result)
# Out:
# [('Amit', 19), ('Raj', 20), ('Ram', 22), ('Neha', 25)]

# %%
14.
marks={
"A":80,
"B":95,
"C":70,
"D":88,
}
result= sorted(marks.items(),key=lambda x:x[1])
print(result)
# Out:
# [('C', 70), ('A', 80), ('D', 88), ('B', 95)]

# %%
15.
words=["apple","banana","kiwi","watermelon"]
result= max(words,key=lambda x: len(x))
print(result)
# Out:
# watermelon

# %%
16.
students=[
("Ram",85),
("Amit",91),
("Neha",78),
]
result= max(students,key=lambda x: x[1])
print(result)
# Out:
# ('Amit', 91)

# %%
17.
employees=[
("A",35000),
("B",42000),
("C",28000),
]
result= min(employees,key=lambda x: x[1])
print(result)
# Out:
# ('C', 28000)

# %%
18.
names = ["ram","amit","neha"]
result= list(map(lambda x: x.upper(),names))
print(result)
# Out:
# ['RAM', 'AMIT', 'NEHA']

# %%
19.
fruits = ["apple","banana","kiwi","orange","grapes"]
result = list(filter(lambda x: len(x)>5,fruits))
print(result)
# Out:
# ['banana', 'orange', 'grapes']

# %%
20.
data=[(1,5),(3,2),(2,8),(4,1)]
result= sorted(data,key=lambda x:x[1])
print(result)
# Out:
# [(4, 1), (3, 2), (1, 5), (2, 8)]

# %%
21.
employees=[
{"name":"Ram","salary":50000},
{"name":"Amit","salary":65000},
{"name":"Neha","salary":45000},
]
result= sorted(employees,key=lambda x:x["salary"])
print(result)
# Out:
# [{'name': 'Neha', 'salary': 45000}, {'name': 'Ram', 'salary': 50000}, {'name': 'Amit', 'salary': 65000}]

# %%
22.
student=[
("Ram",90),
("Amit",90),
("Neha",85),
("Raj",95)
]
descending=sorted(student,key=lambda x:(x[-1],x[0]))
print(descending)
# Out:
# [('Neha', 85), ('Amit', 90), ('Ram', 90), ('Raj', 95)]

# %%
23.
multiply = lambda x: lambda y: x * y
print(multiply(5)(10))
# Out:
# 50

# %%
24.
square = lambda x:x*x
print(square(6))
# Out:
# 36

# %%
25.
numbers= [-5,10,-3,8,0,-1,20]
result= list(filter(lambda x:x>=0,numbers))
print(result)
# Out:
# [10, 8, 0, 20]

# %%
26.
numbers=[1,2,3,4,5,6]
result=list(map(lambda x:x**2 if x%2!=0 else x,numbers))
print(result)
# Out:
# [1, 2, 9, 4, 25, 6]

# %%
27.
fruits=["apple","banana","kiwi","grape"]
result=sorted(fruits,key=lambda x:x[-1])
print(result)
# Out:
# ['banana', 'apple', 'grape', 'kiwi']

# %%
28.
employees = [
("A",45000),
("B",60000),
("C",52000),
("D",75000)
]
result=max(employees,key=lambda x:x[-2])
print(result)
# Out:
# ('D', 75000)

# %%
30.
employees = [
{"name":"Ram","age":25,"salary":50000},
{"name":"Amit","age":25,"salary":60000},
{"name":"Neha","age":23,"salary":45000},
{"name":"Raj","age":27,"salary":55000}
]
descending=sorted(,key=lambda x:(x[0],x[-1],x[1]))
print(descending)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       1 30.
#       2 employees = [
#       3 {"name":"Ram","age":25,"salary":50000},
#       4 {"name":"Amit","age":25,"salary":60000},
#       5 {"name":"Neha","age":23,"salary":45000},
#       6 {"name":"Raj","age":27,"salary":55000}
#       7 ]
# ----> 8 descending = sorted(student,key=lambda x:(x[0],x[-1],x[1]))
#       9 print(descending)
#
# NameError: name 'student' is not defined
