# %% [markdown]
# ### Practical Questions on String Methods & Lists with Difficulty Levels

# %% [markdown]
# ### Easy Level

# %%
1.
name="my name is shruti"
name=name.replace(" " , "_")
name
# Out:
# 'my_name_is_shruti'

# %%
2.
name="    my name is shruti    "
name=name.strip(" ")
name
# Out:
# 'my name is shruti'

# %%
3.
name="Hello, how can I help you?"
name= (name.startswith("Hello"))
name
# Out:
# True

# %%
4.
name="Hello! Listen! "
name=(name.endswith(".com"))
name
# Out:
# False

# %%
5.
name="apple,banana,mango"
name=name.split(",")
name
# Out:
# ['apple', 'banana', 'mango']

# %%
6.
list=["grapes","kivi","pineapple","orange","mango"]
(" ".join(list))
list
# Out:
# ['grapes', 'kivi', 'pineapple', 'orange', 'mango']

# %%
7.
list=["python","is","awesome"]
list[0]=list[0].strip()
list[1]=list[1].strip()
list[2]=list[2].strip()
list
# Out:
# ['python', 'is', 'awesome']

# %%
list=("_".join (list))
list
# Out:
# 'python_is_awesome'

# %% [markdown]
# ### Medium Level

# %%
8.
name="Rahul Kumar Sharma"
name=name.split("Kumar")
name
# Out:
# ['Rahul ', ' Sharma']

# %%
9.
name=input("enter the comment")
name=name.split(" ")
name
# Out:
# enter the comment The children are making noise
# ['The', 'children', 'are', 'making', 'noise']

# %%
10.
name=input("enter the email:")
name=(name.endswith("gmail.com"))
name
# Out:
# enter the email: deshmukhshruti260@gmail.com
# True

# %%
11.
name="Hello World Python"
name=name.replace("World","Everyone")
name
# Out:
# 'Hello Everyone Python'

# %%
12.
list=input("City Name:")
print ("List\n",list)
# Out:
# City Name: Mumbai,Nagpur,Nashik,Pune,Delhi
# List
#  Mumbai,Nagpur,Nashik,Pune,Delhi

# %%
13.
name="hello world"
name=name.strip()
name
name=name.title()
name=(name.startswith("Hello"))
name
# Out:
# True

# %%
14.
name=input("enter the name:")
name=name.split(" ")
name
# Out:
# enter the name: The weather is bad today
# ['The', 'weather', 'is', 'bad', 'today']

# %%
name=("".join(name))
name
# Out:
# 'The_weather_is_bad_today'

# %%
15.
list = ["10", "20", "30", "40"]
list = (" - ".join(list))
list
# Out:
# '10 - 20 - 30 - 40'

# %% [markdown]
# ### Hard Level

# %%
16.
name=input("enter the sentence:")
name=name.split(" ")
name
# Out:
# enter the sentence: Joe waited for the train
# ['Joe', 'waited', 'for', 'the', 'train']

# %%
17.
s = input("Enter a string:")
s = s.replace(" ","-")
words = s.split("-")
for word in words:
    if len(word) > 4:
        print(word)
# Out:
# Enter a string: I am happy
# happy

# %%
18.
students = ["Disha","Swati","Sanskruti","Kiran"]

joined_names = " , ".join(students)
print("Student Names:",joined_names)

students[0] = "New students"
print("Updated List:",students)
# Out:
# Student Names: Disha , Swati , Sanskruti , Kiran
# Updated List: ['New students', 'Swati', 'Sanskruti', 'Kiran']

# %%
19.
paragraph = input("Enter a paragraph:")
sentences = paragraph.split(".")
result = "\n-".join(sentences)
print("-" + result)
# Out:
# Enter a paragraph: A paragraph is a distinct section of writing that contains a unified set of sentences or a single sentence exploring one central idea. It serves as a visual and logical building block in longer texts, usually starting on a new line and indented or separated by spacing
# -A paragraph is a distinct section of writing that contains a unified set of sentences or a single sentence exploring one central idea
# - It serves as a visual and logical building block in longer texts, usually starting on a new line and indented or separated by spacing

# %%
20.
text = input("Enter a string:")

text = text.strip()
text = text.replace('"','')
words = text.split()

Sentence = sentence.capitalize() + "."
print("formatted sentence:")
print(sentence)
# Out:
# Enter a string: "Disha" "Shruti" "Swati" "Sanskruti"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 text = text.replace("_"," ")
#       6 words = text.split()
# ----> 7 Sentence = sentence.capitalize() + "."
#       8 print("formatted sentence:")
#       9 print(sentence)
#
# NameError: name 'sentence' is not defined
