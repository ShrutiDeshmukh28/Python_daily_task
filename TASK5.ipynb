# %% [markdown]
# ### Practical Questions on Python Lists

# %% [markdown]
# ### Easy Level

# %%
1.
student=["Priti","Shruti","Snehal","Payal","Pratiksha"]
print(student)
type(student)
# Out:
# ['Priti', 'Shruti', 'Snehal', 'Payal', 'Pratiksha']
# list

# %%
2.
lists=[10,20,30,40,50]
lists=type(lists)
print(lists)
# Out:
# <class 'list'>

# %%
3.
number=[]
number1=["15","16","17"]
number=number.append(number1)
print(number)
# Out:
# None

# %%
4.
lst=[1,2,3]
lst.extend(["4,5,6"])
print(lst)
# Out:
# [1, 2, 3, '4,5,6']

# %%
5.
lst = [10,20,30,40]
lst.insert(2,"100")
print(lst)
# Out:
# [10, 20, '100', 30, 40]

# %%
6.
lst=[10,20,50,30,50]
lst.remove(50)
print(lst)
# Out:
# [10, 20, 30, 50]

# %%
7.
lst=[5,10,15,20]
lst.pop()
print(lst)
# Out:
# [5, 10, 15]

# %%
8.
list_data=[1,2,3,4,5]
list_data.clear()
list_data
# Out:
# []

# %% [markdown]
# ### Medium Level

# %%
9.
lst=[10,15,25,30,40]
lst.index(25)
lst
# Out:
# [10, 15, 25, 30, 40]

# %%
10.
lst=[7,2,7,5,7,8]
print(lst.count(7))
# Out:
# 3

# %%
11.
lst=[45,12,78,23,56]
lst.sort()
lst
# Out:
# [12, 23, 45, 56, 78]

# %%
12.
lst=[45,12,78,23,56]
lst.sort(reverse=True)
lst
# Out:
# [78, 56, 45, 23, 12]

# %%
13.
fruits=["apple","banana","mango","orange"]
fruits.reverse()
fruits
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
14.
lst=[1,2,3,4]
print(lst)
new_lst=lst.copy()
new_lst
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
15.
name = (input("Take a sen.:"))
name=name.split()
name
# Out:
# Take a sen.: I love Python programming
# ['I', 'love', 'Python', 'programming']

# %% [markdown]
# ### Hard / Mixed Level

# %%
16.
numbers = [25, 10, 45, 30, 15]
numbers.append(50)
numbers.append(5)
numbers.append(40)
numbers.sort(reverse=True)
print("Sorted List (Descending):", numbers)
# Out:
# Sorted List (Descending): [50, 45, 40, 30, 25, 15, 10, 5]

# %%
17.
lists = ["Love","Python","Programming"]
print(lists.insert(0,"Python"))
lists.pop()
lists
# Out:
# None
# ['Python', 'Love', 'Python']

# %%
18.
lst0=(input("city1:")) 
lst1=(input("city1:")) 
lst2=(input("city1:")) 
lst3=(input("city1:"))
lst4=(input("city1:"))
lst=(lst0 + lst1 + lst2 + lst3 + lst4)
print(lst)
# Out:
# city1: surat
# city1: mumbai
# city1: pune
# city1: nashik
# city1: delhi
# suratmumbaipunenashikdelhi

# %%
19.
data=[10,20,30,20,40,20]
print(data.count(20))
data.remove(20)
data.remove(20)
data
# Out:
# 3
# [10, 30, 40, 20]

# %%
20.
marks = [78, 92, 65, 88, 95, 70]
marks.sort()
lowest = marks[0]
highest = marks[-1]
print("Sorted Marks:", marks)
print("Lowest Mark:",lowest)
print("Highest Mark:",highest)
# Out:
# Sorted Marks: [65, 70, 78, 88, 92, 95]
# Lowest Mark: 65
# Highest Mark: 95
