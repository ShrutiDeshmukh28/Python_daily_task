# %% [markdown]
# ### Practical Questions on Sets and If Statements

# %% [markdown]
# ### Set Questions

# %%
1.
sets = {1, 2, 3, 2, 4, 1}
sets
# Out:
# {1, 2, 3, 4}

# %%
2.
my_set = set()
my_set.add(1)
my_set.add(2)
my_set.add(3)
print(my_set)
# Out:
# {1, 2, 3}

# %%
3.
s = {10, 20, 30}
s1 = [40, 50, 60]
s.update(s1)
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
4.
s = {10, 20, 30, 40}
s.remove(20)
s
# Out:
# {10, 30, 40}

# %%
5.
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A.intersection(B)
# Out:
# {3, 4}

# %%
A.difference(B)
# Out:
# {1, 2}

# %%
6.
s = {10, 20, 30, 40}
is_present = 25 in s
print(is_present)
# Out:
# False

# %%
7.
list1 = [1, 2, 2, 3, 4, 4, 5]
len(list1)
# Out:
# 7

# %%
8.
unique_numbers = set()
for i in range(5):
    num = int(input(f"Enter number{i + 1}:"))
    unique_numbers.add(num)
print("Unique numbers:",unique_numbers)
# Out:
# Enter number1: 2
# Enter number2: 3
# Enter number3: 4
# Enter number4: 5
# Enter number5: 6
# Unique numbers: {2, 3, 4, 5, 6}

# %% [markdown]
# 9.
# A = {1, 2, 3}
# B = {3, 4, 5}
# A.difference(B)

# %%
10.
s = [1,2,3]
s2 = [1,2,3]
s.add[1]
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       2 s = [1,2,3]
#       3 s2 = [1,2,3]
# ----> 4 s.add[1]
#       5 print(s)
#
# AttributeError: 'list' object has no attribute 'add'

# %% [markdown]
# ### If Statement Questions

# %%
11.
age = 23
if age>=18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
12.
number = float(input("give the no.:"))
if number > 0:
    print("positive")
elif number >= 0:
    print("zero")
else:
    print("negative")
# Out:
# give the no.: 20
# positive

# %%
13.
num1 = float(input("give the no.:"))
num2 = float(input("give the no.:"))
if num1 > num2 :
    print("larger")
else:
    print("smaller")
# Out:
# give the no.: 30
# give the no.: 40
# smaller

# %%
14.
A = input("enter the character:")
vowel = ("a","e","i","o","u")
if A == vowel:
    print("vowel")
else:
    print("constant")
# Out:
# enter the character: p
# constant

# %%
15.
i = float(input("Swati marks:"))
if i >= 90:
    print("A")
elif i >= 80:
    print("B")
elif i >= 70:
    print("C")
else:
    print("fail")
# Out:
# Swati marks: 70
# C

# %%
16.
A = 45
X = 60
Y = 35
if (A >= X and A >=Y):
    print ("largest is A")
elif (X >= A and X>=Y):
    print("largest is X")
else:
    print("largest is Y")
# Out:
# largest is X

# %%
17.
num = 80
if (num>=50)/2:
    print("largest and even")
else:
    print("smallest")
# Out:
# largest and even

# %%
18.
username = input("Enter username:")
password = input("Enter password:")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username: asdg
# Enter password: 456
# Login Failed

# %%
19.
year = input("year:")
if (year % 400 ==0 and year % 100 !=0) or (year % 100 ==0):
    print("leap year")
else:
    print("regular year")
# Out:
# year: 2002
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 19.
#       2 year = input("year:")
# ----> 3 if (year % 400 ==0 and year % 100 !=0) or (year % 100 ==0):
#       4     print("leap year")
#       5 else:
#
# TypeError: not all arguments converted during string formatting

# %%
20.
A = 40
B = 50
C = 60
if A + B > C:
    print("its triangle")
else:
    print("its not a triangle")
# Out:
# its triangle

# %% [markdown]
# ### Hard

# %%
1.
A = float(input("Enter triangle side:"))
B = float(input("Enter triangle side:"))
C = float(input("Enter triangle side:"))
if (A>=B) and (B>=C) and (A>=C):
    print("largest number")
else:
    print("smallest")
# Out:
# Enter triangle side: 45
# Enter triangle side: 40
# Enter triangle side: 40
# largest number

# %%
2.
year = input("year:")
if(year/4==0 and year/100!=0 or year/100==0):
    print("leap year")
else:
    print("regular year")
# Out:
# year: 2002
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 2.
#       2 year = input("year:")
# ----> 3 if(year/4==0 and year/100!=0 or year/100==0):
#       4     print("leap year")
#       5 else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
3.
A = float(input("Enter triangle side:"))
B = float(input("Enter triangle side:"))
C = float(input("Enter triangle side:"))
if (A+B>C) and (B+C>A) and (A+C>B):
    print("triangle")
elif (A==B)and(B==C) and (A==C):
    print("issosceles")
elif (A!=B) and (B!=C) and (A!=C):
    print("Equilateral")
else:
    print("smallest")
# Out:
# Enter triangle side: 25
# Enter triangle side: 35
# Enter triangle side: 55
# triangle

# %%
24.
marks1 = input("Enter the marks:")
marks2 = input("Enter the marks:")
marks3 = input("Enter the marks:")
marks4 = input("Enter the marks:")
marks5 = input("Enter the marks:")
total_marks = marks1 + marks2 + marks3 + marks4 + marks5
percentage = (total_marks/500)*100
for percentage = 90:
    print("A+")
elif percentage >= 80:
    print("B")
elif percentage >= 70:
    print("C")
elif percentage >= 60:
    print("fail")

if percentage >= 75:
    print("Pass on exection")
# Out:
#   Cell In[38], line 9
#     for percentage = 90:
#                    ^
# SyntaxError: invalid syntax

# %%
25.
username = input("Enter username:")
password = input("Enter password:")

if username == "admin" and password == "python 1234" and age>=18:
    print("Login Successful")
elif age<18:
    prin
else:
    print("Login Failed")
