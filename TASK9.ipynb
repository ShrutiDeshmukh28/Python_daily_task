# %%
1.
 n = int(input("Enter a number: "))
if n > 0: 
    if n % 2 == 0:
       print ("Positive Even")
    else:
        print ("Positive Odd")
else:
    print("Number is not positive")
# Out:
# Enter a number:  20
# Positive Even

# %%
2.
age = int(input("Enter age:"))
if age >= 18:
    if age >= 60:
        print("Senior Citizen")
    else:
        print("youth")
else:
    print("child/teenager")
# Out:
# Enter age: 46
# youth

# %%
3.
ch = input ("Enter a character:")
if len(ch)==1:
    if ch.islower():
        print(f"'{ch}' is a lowercase alphabet.")
    else:
        print(f"'{ch}' is a lowercase alphabet.")
else:
    print(f"'{ch}' is not an alphabetic character.")
# Out:
# Enter a character: v
# 'v' is a lowercase alphabet.

# %%
4.
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))
num3 = float(input("Enter third number:"))
if num1 >= num2:
    if num1 >= num3:
        largest = num1
    else:
        largest = num3
else:
    if num2 >= num3:
        largest = num2
    else:
        largest = num3
print("The largest number is:",largest)
# Out:
# Enter first number: 30
# Enter second number: 50
# Enter third number: 80
# The largest number is: 80.0

# %%
5.
marks = float(input("Enter student marks:"))
if marks >= 40:
    if marks >=75:
        print("pass with Distinction")
    else:
        print("Pass")
else:
    print("Fail")
# Out:
# Enter student marks: 69
# Pass

# %%
6.
n = int(input("Enter an integer:"))
if n % 2 == 0:
    if n % 4 == 0:
        print("Divisible by 2 and 4")
    else:
        print("Divisible by 2 not by 4")
else:
    print("Not Divisible by 2 therefore notby 4")
# Out:
# Enter an integer: 678
# Divisible by 2 not by 4

# %%
7.
user = input("username:")
pas = input("password:")
if user == "admin":
    if pas =="1234":
        print("login successful")
    else:
        print("Incorrect password")
else:
    print("Invalid username")
# Out:
# username: admin
# password: 1234
# login successful

# %%
8.
a = float(input("Enter length of side A:"))
b = float(input("Enter length of side B:"))
c = float(input("Enter length of side C:"))
if (a + b > c) and (a + c > b) and (b + c > a):
     print("The sides from a valid triangle")
     if a == b == c:
         print("Equilateral all side are equal")
     elif a == b or b == c or a == c:
         print("Isosceles all side are equal")
     else:
         print("Scalene all side are different")
else:
     print("Invalid Triangle! the sum of ant two sides must be greater than the third side ")
# Out:
# Enter length of side A: 50
# Enter length of side B: 60
# Enter length of side C: 70
# The sides from a valid triangle
# Scalene all side are different

# %%
9.
salary = float(input(" Enter Annunal Salary:"))
exp = float(input(" Enter years of Experience:"))
if salary > 50000:
      if exp >= 5:
          print("senior manager")
      else:
          print("manager")
else:
    print("Associate/specialist(salary is 50000 or less)")
# Out:
#  Enter Annunal Salary: 80000
#  Enter years of Experience: 3
# manager

# %%
10.
char = input("Enter a single character:")

if len(char)==1:
    
    if char.isalpha():
       lower_char = char.lower()
        
       if lower_char in ['a','e','i','o','u']:
           print(f"'{char}'is a letter vowel")
       else:
           print(f"'{char}'is a letter consonant")
           
    elif char.isdigit():
       print(f"'{char}is a digit'Digit")
    else:
       print(f"'{char} is a special character")
             
else:
    print("please enter exactly one character")
# Out:
# Enter a single character: abc
# please enter exactly one character

# %%
11.
year = int(input("Enter year:"))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
           print(f"{year}is a Leap year")
        else:
           print(f"{year}is not a leap year")
    else:
        print(f" {year}is a Leap year")
else:
    print(f"{year}is not a leap year")
# Out:
# Enter year: 2002
# 2002is not a leap year

# %%
12.
temp = int(input("Enter the Temperature:"))
if temp >30:
   print ("hot")
elif temp >=20 and temp <=30:
    print ("warm")
else:
    print("cold")
# Out:
# Enter the Temperature: 45
# hot

# %%
13.
a = int(input("Enter the number:"))
b = int(input("Enter the number:"))
c = int(input("Enter the number:"))
if a == b:
    if b==c:
        print(f"the num.{a} is equal")
    else:
         print(f"the num.{a} and{b} equal")
else:
    if a == c:
         print(f"the num.{a} and {c} is equal")
    else:
         print ("the num. is different")
# Out:
# Enter the number: 45
# Enter the number: 55
# Enter the number: 45
# the num.45 and 45 is equal

# %%
14.
N = int(input("enter number:"))
if n > 0:
    if n % 2 == 0:
        print("Positive Even Number")
    else:
        print("Positive Odd Number")
else:
    print("Negative Even Number")
# Out:
# enter number: 12
# Positive Even Number

# %%
15.
a = int(input("Enter the number:"))
b = int(input("Enter the number:"))
c = int(input("Enter the number:"))
d = int(input("Enter the number:"))
e = int(input("Enter the number:"))
total_marks= a + b + c + d + e
if total_marks>=60:
    if a>40 and b>40 and c>40 and d>40 and e>40:
         print("Excellent marks")
    else:
         print("pass")
else:
    print("fail")
# Out:
# Enter the number: 78
# Enter the number: 88
# Enter the number: 89
# Enter the number: 77
# Enter the number: 75
# Excellent marks

# %%
16.
ID = "admin"
Password = 1234
Eligible =18

user_name = (input("Enter the name:"))
password = int(input("Enter the number:"))
age = int(input("Enter the age:"))

if ID == user_name:
    if password == password and eligible>=age:
        print("Login Successfull")
    else:
        print("the eligibility is not satisfied")
else:
    print("not the valid user")
# Out:
# Enter the name: shruti
# Enter the number: 1234
# Enter the age: 18
# not the valid user

# %%
17.
number = int(input("Enter an integer:"))
if number % 3 == 0:
    if number % 5 == 0:
        print("The number is divisible by 3 and also by 5")
    else:
        print("The number is divisible by 3 but not by 5") 
else:
    print("The number is not divisible by 3 and but by 5")
# Out:
# Enter an integer: 55
# The number is not divisible by 3 and but by 5

# %%
18.
a = int(input("Enter an integer:"))
b = int(input("Enter an integer:"))
c = int(input("Enter an integer:"))
if (a+b>c) and (b+c>a) and (a+c>b):
    print("valid triangle")
    if a**2 + b**2 == c**2 and a**2 + c**2 == b**2 and c**2 + b**2 == a**2:
        print("its a right angle triangle")
    else:
        print("its a triangle")
else:
    print("invalid triangle")
# Out:
# Enter an integer: 23
# Enter an integer: 23
# Enter an integer: 23
# valid triangle
# its a triangle

# %%
19.
A = int(input("Enter the number:"))
B = int(input("Enter the number:"))
C = int(input("Enter the number:"))
D = int(input("Enter the number:"))
F = int(input("Enter the number:"))
total_marks = A + B + C + D + F 
percentage = (total_marks/500)*100
if percentage>=65:
    print("pass")
    if percentage >= 90:
       print("Excellent")

    else:
       if percentage>=70:
           print("Good")
           print("Average")
else:
     if percentage>=60:
         print("Good")
     else:
         print("Fail")
# Out:
# Enter the number: 35
# Enter the number: 35
# Enter the number: 65
# Enter the number: 78
# Enter the number: 10
# Fail

# %%
20.
income = int(input("Enter the salary:"))
if salary>1000000:
     if salary >= income:
         print("20% tax slab on total income ")
     else: 
         if salary>= 500000 and salary<=1000000:
             print("15% tax slab on total income")
else:
    print("low income")
# Out:
# Enter the salary: 2500000
# low income

# %% [markdown]
# ### Extra More Question

# %%
1.
a = int(input("Enter an integer:"))
b = int(input("Enter an integer:"))
c = int(input("Enter an integer:"))
if (a+b>c) and (b+c>a) and (a+c>b):
    print("valid triangle")
    if a==b==c:
        print(" the triangle is Equilateral")
    else:
        if a==b and b!=c:
            print("the triangle is Isosceles")
else:
    print("invalid triangle")
# Out:
# Enter an integer: 38
# Enter an integer: 38
# Enter an integer: 1
# valid triangle
# the triangle is Isosceles

# %%
2.
A = int(input("Enter the marks:"))
B = int(input("Enter the marks:"))
C = int(input("Enter the marks:"))
D = int(input("Enter the marks:"))
E = int(input("Enter the marks:"))

average = (A + B + C + D + E)/5

if average >=60:
    if A>=40 and B>=40 and C>=40 and D>=40 and E>=40:
         print("Pass with Good Performance")
    else: 
         print ("Pass but weak in some subject")
else:
    print("fail")
# Out:
# Enter the marks: 99
# Enter the marks: 88
# Enter the marks: 90
# Enter the marks: 95
# Enter the marks: 75
# Pass with Good Performance

# %%
3.
user_name = input("Enter the Username:")
password = input("Enter the password:")
age = int(input("Enter the age:"))

if username == "admin":
    if password == "python123":
        if age >= 18:
             print("Login Successfull")
    else:
        print("Invalid password")
else:
    print("Invalid username")
# Out:
# Enter the Username: admin
# Enter the password: python
# Enter the age: 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 6
#       3 password = input("Enter the password:")
#       4 age = int(input("Enter the age:"))
# ----> 6 if username == "admin":
#       7     if password == "python123":
#       8         if age >= 18:
#
# NameError: name 'username' is not defined

# %%
4.
num = int(input("Enter a number: "))

if num < 0:
    print("Negative Number")
else:
    if num % 3 == 0 and num % 5 == 0:
        print("FizzBuzz")
    elif num % 3 == 0:
        print("Fizz")
    elif num % 5 == 0:
        print("Buzz")
    else:
        print("Number is not divisible by 3 or 5")
# Out:
# Enter a number:  15
# FizzBuzz

# %%
5.
A = int(input("Enter the first number: "))
B = int(input("Enter the second number: "))
C = int(input("Enter the third number: "))

if A == B == C:
    print("All three numbers are equal")
else:
    if A >= B and A >= C:
        largest = A
    elif B >= A and B >= C:
        largest = B
    else:
        largest = C

    print("Largest number is:", largest)

    if largest % 2 == 0:
        print("Largest number is Even")
    else:
        print("Largest number is Odd")
